# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name:
# * Student pace: self paced / part time / full time
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:

# %%
#imports
import numpy as np
from scipy import stats
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# %%
budget = pd.read_csv('zippedData/tn.movie_budgets.csv')

# %%
budget.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
budget.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %%
#change dates to datetime objects
budget['release_date'] = pd.to_datetime(budget['release_date'])

# %%
#remove commas from gross figures
budget = budget.replace(',','', regex=True)

# %%
#make this one line if possible
budget['production_budget']= budget['production_budget'].str[1:]
budget['domestic_gross'] = budget['domestic_gross'].str[1:]
budget['worldwide_gross'] = budget['worldwide_gross'].str[1:]

# %%
#convert production budget, domestic gross, and worldwide gross to integers from objects
budget[['production_budget', 'domestic_gross', 'worldwide_gross']] = budget[['production_budget', 'domestic_gross', 'worldwide_gross']].astype(np.int64)

# %%
budget.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   datetime64[ns]
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   int64
#  4   domestic_gross     5782 non-null   int64
#  5   worldwide_gross    5782 non-null   int64
# dtypes: datetime64[ns](1), int64(4), object(1)
# memory usage: 271.2+ KB

# %%
#Create a new column to determine how much a movie made against its budget
budget["return_on_investment"]= budget['worldwide_gross']/budget['production_budget']

# %%
#Convert the release date to a date time format
budget['year'] = budget['release_date'].dt.year

# %%
#Filter by year after 2010
budget_recent = budget.loc[budget['year']>2010]

# %%
budget_recent['return_on_investment'].describe()
# Out:
# count    1920.000000
# mean        3.285546
# std        11.055955
# min         0.000000
# 25%         0.200260
# 50%         1.613252
# 75%         3.635941
# max       416.564740
# Name: return_on_investment, dtype: float64

# %%
#Filter by return on investment greater than 2, considering these to be successful movies
#success = budget_recent.loc[budget['return_on_investment']>1]

# %%
budget_recent.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1920 entries, 1 to 5780
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    1920 non-null   int64
#  1   release_date          1920 non-null   datetime64[ns]
#  2   movie                 1920 non-null   object
#  3   production_budget     1920 non-null   int64
#  4   domestic_gross        1920 non-null   int64
#  5   worldwide_gross       1920 non-null   int64
#  6   return_on_investment  1920 non-null   float64
#  7   year                  1920 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(5), object(1)
# memory usage: 135.0+ KB

# %%
#Export success df to .csv
#success.to_csv("zippedData/budget_all_movies.csv")

# %% [markdown]
# ### Merging the budget dataframe with the IMDB data pulled from SQL

# %%
#imports and connect to SQL
import sqlite3
import pandasql


conn = sqlite3.connect('zippedData/im.db')

# %%
#creating a dataframe with the info we want to take from the imdb database
imdb_ratings = pd.read_sql(
    """
    SELECT basics.movie_id, basics.primary_title, basics.original_title, basics.runtime_minutes, basics.genres, ratings.averagerating, ratings.numvotes
    FROM movie_basics as basics
        JOIN movie_ratings as ratings
            USING(movie_id)
    """, conn
)

# %%
imdb_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   movie_id         73856 non-null  object
#  1   primary_title    73856 non-null  object
#  2   original_title   73856 non-null  object
#  3   runtime_minutes  66236 non-null  float64
#  4   genres           73052 non-null  object
#  5   averagerating    73856 non-null  float64
#  6   numvotes         73856 non-null  int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 3.9+ MB

# %%
imdb_ratings
# Out:
#         movie_id                    primary_title              original_title  \
# 0      tt0063540                        Sunghursh                   Sunghursh
# 1      tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2      tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3      tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4      tt0100275         The Wandering Soap Opera       La Telenovela Errante
# ...          ...                              ...                         ...
# 73851  tt9913084                 Diabolik sono io            Diabolik sono io
# 73852  tt9914286                Sokagin Çocuklari           Sokagin Çocuklari
# 73853  tt9914642                        Albatross                   Albatross
# 73854  tt9914942       La vida sense la Sara Amat  La vida sense la Sara Amat
# 73855  tt9916160                       Drømmeland                  Drømmeland
#
#        runtime_minutes                genres  averagerating  numvotes
# 0                175.0    Action,Crime,Drama            7.0        77
# 1                114.0       Biography,Drama            7.2        43
# 2                122.0                 Drama            6.9      4517
# 3                  NaN          Comedy,Drama            6.1        13
# 4                 80.0  Comedy,Drama,Fantasy            6.5       119
# ...                ...                   ...            ...       ...
# 73851             75.0           Documentary            6.2         6
# 73852             98.0          Drama,Family            8.7       136
# 73853              NaN           Documentary            8.5         8
# 73854              NaN                  None            6.6         5
# 73855             72.0           Documentary            6.5        11
#
# [73856 rows x 7 columns]

# %%
#bring in csv that was cleaned with the movie budgets
#budget_cleaned = pd.read_csv('zippedData/budget_all_movies.csv')

# %%
#removing duplicates from the movie title column in each dataframe before merging them
imdb_ratings = imdb_ratings.drop_duplicates(subset=['primary_title'])
budget_recent = budget_recent.drop_duplicates(subset=['movie'])

# %%
budget_recent
# Out:
#       id release_date                                        movie  \
# 1      2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2      3   2019-06-07                                 Dark Phoenix
# 3      4   2015-05-01                      Avengers: Age of Ultron
# 4      5   2017-12-15            Star Wars Ep. VIII: The Last Jedi
# 5      6   2015-12-18         Star Wars Ep. VII: The Force Awakens
# ...   ..          ...                                          ...
# 5761  62   2014-12-31                         Stories of Our Lives
# 5771  72   2015-05-19                             Family Motocross
# 5772  73   2012-01-13                                    Newlyweds
# 5777  78   2018-12-31                                       Red 11
# 5780  81   2015-09-29                         A Plague So Pleasant
#
#       production_budget  domestic_gross  worldwide_gross  \
# 1             410600000       241063875       1045663875
# 2             350000000        42762350        149762350
# 3             330600000       459005868       1403013963
# 4             317000000       620181382       1316721747
# 5             306000000       936662225       2053311220
# ...                 ...             ...              ...
# 5761              15000               0                0
# 5771              10000               0                0
# 5772               9000            4584             4584
# 5777               7000               0                0
# 5780               1400               0                0
#
#       return_on_investment  year
# 1                 2.546673  2011
# 2                 0.427892  2019
# 3                 4.243841  2015
# 4                 4.153696  2017
# 5                 6.710167  2015
# ...                    ...   ...
# 5761              0.000000  2014
# 5771              0.000000  2015
# 5772              0.509333  2012
# 5777              0.000000  2018
# 5780              0.000000  2015
#
# [1918 rows x 8 columns]

# %%
imdb_ratings
# Out:
#         movie_id                    primary_title              original_title  \
# 0      tt0063540                        Sunghursh                   Sunghursh
# 1      tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2      tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3      tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4      tt0100275         The Wandering Soap Opera       La Telenovela Errante
# ...          ...                              ...                         ...
# 73849  tt9911774        Padmavyuhathile Abhimanyu   Padmavyuhathile Abhimanyu
# 73850  tt9913056                     Swarm Season                Swarm Season
# 73851  tt9913084                 Diabolik sono io            Diabolik sono io
# 73852  tt9914286                Sokagin Çocuklari           Sokagin Çocuklari
# 73854  tt9914942       La vida sense la Sara Amat  La vida sense la Sara Amat
#
#        runtime_minutes                genres  averagerating  numvotes
# 0                175.0    Action,Crime,Drama            7.0        77
# 1                114.0       Biography,Drama            7.2        43
# 2                122.0                 Drama            6.9      4517
# 3                  NaN          Comedy,Drama            6.1        13
# 4                 80.0  Comedy,Drama,Fantasy            6.5       119
# ...                ...                   ...            ...       ...
# 73849            130.0                 Drama            8.4       365
# 73850             86.0           Documentary            6.2         5
# 73851             75.0           Documentary            6.2         6
# 73852             98.0          Drama,Family            8.7       136
# 73854              NaN                  None            6.6         5
#
# [69993 rows x 7 columns]

# %%
#merge imdb data with our movie budget data
all_movie_data = pd.merge(budget_recent, imdb_ratings, left_on='movie', right_on='primary_title', how='inner')

# %%
all_movie_data
# Out:
#       id release_date                                        movie  \
# 0      2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 1      3   2019-06-07                                 Dark Phoenix
# 2      4   2015-05-01                      Avengers: Age of Ultron
# 3      7   2018-04-27                       Avengers: Infinity War
# 4      9   2017-11-17                               Justice League
# ...   ..          ...                                          ...
# 1586  59   2011-11-25                                   The Ridges
# 1587  62   2014-12-31                         Stories of Our Lives
# 1588  73   2012-01-13                                    Newlyweds
# 1589  78   2018-12-31                                       Red 11
# 1590  81   2015-09-29                         A Plague So Pleasant
#
#       production_budget  domestic_gross  worldwide_gross  \
# 0             410600000       241063875       1045663875
# 1             350000000        42762350        149762350
# 2             330600000       459005868       1403013963
# 3             300000000       678815482       2048134200
# 4             300000000       229024295        655945209
# ...                 ...             ...              ...
# 1586              17300               0                0
# 1587              15000               0                0
# 1588               9000            4584             4584
# 1589               7000               0                0
# 1590               1400               0                0
#
#       return_on_investment  year   movie_id  \
# 0                 2.546673  2011  tt1298650
# 1                 0.427892  2019  tt6565702
# 2                 4.243841  2015  tt2395427
# 3                 6.827114  2018  tt4154756
# 4                 2.186484  2017  tt0974015
# ...                    ...   ...        ...
# 1586              0.000000  2011  tt1781935
# 1587              0.000000  2014  tt3973612
# 1588              0.509333  2012  tt1880418
# 1589              0.000000  2018  tt7837402
# 1590              0.000000  2015  tt2107644
#
#                                     primary_title  \
# 0     Pirates of the Caribbean: On Stranger Tides
# 1                                    Dark Phoenix
# 2                         Avengers: Age of Ultron
# 3                          Avengers: Infinity War
# 4                                  Justice League
# ...                                           ...
# 1586                                   The Ridges
# 1587                         Stories of Our Lives
# 1588                                    Newlyweds
# 1589                                       Red 11
# 1590                         A Plague So Pleasant
#
#                                    original_title  runtime_minutes  \
# 0     Pirates of the Caribbean: On Stranger Tides            136.0
# 1                                    Dark Phoenix            113.0
# 2                         Avengers: Age of Ultron            141.0
# 3                          Avengers: Infinity War            149.0
# 4                                  Justice League            120.0
# ...                                           ...              ...
# 1586                                   The Ridges             89.0
# 1587                         Stories of Our Lives             60.0
# 1588                                    Newlyweds             95.0
# 1589                                       Red 11             77.0
# 1590                         A Plague So Pleasant             76.0
#
#                         genres  averagerating  numvotes
# 0     Action,Adventure,Fantasy            6.6    447624
# 1      Action,Adventure,Sci-Fi            6.0     24451
# 2      Action,Adventure,Sci-Fi            7.3    665594
# 3      Action,Adventure,Sci-Fi            8.5    670926
# 4     Action,Adventure,Fantasy            6.5    329135
# ...                        ...            ...       ...
# 1586     Drama,Horror,Thriller            2.9       127
# 1587                     Drama            7.5        85
# 1588              Comedy,Drama            6.4      1436
# 1589    Horror,Sci-Fi,Thriller            5.6        43
# 1590     Drama,Horror,Thriller            5.4        72
#
# [1591 rows x 15 columns]

# %%
#Checking for duplicates of movie titles in our dataset that we will use going forward for analyses
all_movie_data['movie'].duplicated().value_counts()
# Out:
# False    1591
# Name: movie, dtype: int64

# %% [markdown]
# ### Analysis of movie success depending on the month of the year, season

# %%
#import mathplotlib
import matplotlib.pyplot as plt

# %%
#Histogram of domestic gross
plt.hist(all_movie_data['domestic_gross'], bins=30, edgecolor='black')
plt.xlabel('Domestic Gross')
plt.ylabel('Frequency')
plt.title('Distribution of Domestic Gross')
plt.show()

# %%
#Create new column for month
all_movie_data['release_date'] = pd.to_datetime(all_movie_data['release_date'])
all_movie_data['release_month'] = all_movie_data['release_date'].dt.month

# %%
all_movie_data
# Out:
#       id release_date                                        movie  \
# 0      2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 1      3   2019-06-07                                 Dark Phoenix
# 2      4   2015-05-01                      Avengers: Age of Ultron
# 3      7   2018-04-27                       Avengers: Infinity War
# 4      9   2017-11-17                               Justice League
# ...   ..          ...                                          ...
# 1586  59   2011-11-25                                   The Ridges
# 1587  62   2014-12-31                         Stories of Our Lives
# 1588  73   2012-01-13                                    Newlyweds
# 1589  78   2018-12-31                                       Red 11
# 1590  81   2015-09-29                         A Plague So Pleasant
#
#       production_budget  domestic_gross  worldwide_gross  \
# 0             410600000       241063875       1045663875
# 1             350000000        42762350        149762350
# 2             330600000       459005868       1403013963
# 3             300000000       678815482       2048134200
# 4             300000000       229024295        655945209
# ...                 ...             ...              ...
# 1586              17300               0                0
# 1587              15000               0                0
# 1588               9000            4584             4584
# 1589               7000               0                0
# 1590               1400               0                0
#
#       return_on_investment  year   movie_id  \
# 0                 2.546673  2011  tt1298650
# 1                 0.427892  2019  tt6565702
# 2                 4.243841  2015  tt2395427
# 3                 6.827114  2018  tt4154756
# 4                 2.186484  2017  tt0974015
# ...                    ...   ...        ...
# 1586              0.000000  2011  tt1781935
# 1587              0.000000  2014  tt3973612
# 1588              0.509333  2012  tt1880418
# 1589              0.000000  2018  tt7837402
# 1590              0.000000  2015  tt2107644
#
#                                     primary_title  \
# 0     Pirates of the Caribbean: On Stranger Tides
# 1                                    Dark Phoenix
# 2                         Avengers: Age of Ultron
# 3                          Avengers: Infinity War
# 4                                  Justice League
# ...                                           ...
# 1586                                   The Ridges
# 1587                         Stories of Our Lives
# 1588                                    Newlyweds
# 1589                                       Red 11
# 1590                         A Plague So Pleasant
#
#                                    original_title  runtime_minutes  \
# 0     Pirates of the Caribbean: On Stranger Tides            136.0
# 1                                    Dark Phoenix            113.0
# 2                         Avengers: Age of Ultron            141.0
# 3                          Avengers: Infinity War            149.0
# 4                                  Justice League            120.0
# ...                                           ...              ...
# 1586                                   The Ridges             89.0
# 1587                         Stories of Our Lives             60.0
# 1588                                    Newlyweds             95.0
# 1589                                       Red 11             77.0
# 1590                         A Plague So Pleasant             76.0
#
#                         genres  averagerating  numvotes  release_month
# 0     Action,Adventure,Fantasy            6.6    447624              5
# 1      Action,Adventure,Sci-Fi            6.0     24451              6
# 2      Action,Adventure,Sci-Fi            7.3    665594              5
# 3      Action,Adventure,Sci-Fi            8.5    670926              4
# 4     Action,Adventure,Fantasy            6.5    329135             11
# ...                        ...            ...       ...            ...
# 1586     Drama,Horror,Thriller            2.9       127             11
# 1587                     Drama            7.5        85             12
# 1588              Comedy,Drama            6.4      1436              1
# 1589    Horror,Sci-Fi,Thriller            5.6        43             12
# 1590     Drama,Horror,Thriller            5.4        72              9
#
# [1591 rows x 16 columns]

# %% [markdown]
# #### Noticed a significant outlier, a movie called "The Gallows"

# %%
#The Gallows data
all_movie_data.loc[all_movie_data["movie"]=="The Gallows"]
# Out:
#       id release_date        movie  production_budget  domestic_gross  \
# 1551  80   2015-07-10  The Gallows             100000        22764410
#
#       worldwide_gross  return_on_investment  year   movie_id primary_title  \
# 1551         41656474             416.56474  2015  tt2309260   The Gallows
#
#      original_title  runtime_minutes                   genres  averagerating  \
# 1551    The Gallows             81.0  Horror,Mystery,Thriller            4.2
#
#       numvotes  release_month
# 1551     17763              7

# %%
#drop outlier before we do analysis
movie_title_to_drop = 'The Gallows'
all_movie_data = all_movie_data.drop(
    all_movie_data[all_movie_data['movie'] == movie_title_to_drop].index,
    axis=0)

# %%
# Create the bar chart
plt.figure(figsize=(20, 6))
plt.bar(all_movie_data['release_month'], all_movie_data['production_budget'])

# Add labels and title
plt.xlabel('Month')
plt.ylabel('Production Budget')
plt.title('Production Budget by Month')

# Customize the x-axis ticks with month names
month_names = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
plt.xticks(all_movie_data['release_month'].unique(), month_names)

# Show the bar chart

plt.show()

# %%
# Bar chart of return on investment by month
plt.figure(figsize=(20, 6))
plt.bar(all_movie_data['release_month'], all_movie_data['return_on_investment'])

plt.xlabel('Month')
plt.ylabel('Return on Investment')
plt.title('Return on Investment by Month')

# Customize the x-axis ticks with month names



plt.show()

# %%
all_movie_data['return_on_investment'].describe()
# Out:
# count    1590.000000
# mean        3.157395
# std         5.849693
# min         0.000000
# 25%         0.280618
# 50%         1.697085
# 75%         3.744135
# max       101.759490
# Name: return_on_investment, dtype: float64

# %%
# Bar chart of domestic gross $ by month
plt.figure(figsize=(20, 6))
plt.bar(all_movie_data['release_month'], all_movie_data['domestic_gross'])

plt.xlabel('Month')
plt.ylabel('Domestic Gross')
plt.title('Domestic Gross by Month')

month_names = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
plt.xticks(all_movie_data['release_month'].unique(), month_names)

plt.show()

# %%
# Bar chart of domestic gross $ by month
plt.figure(figsize=(20, 6))
plt.bar(all_movie_data['release_month'], all_movie_data['worldwide_gross'])

plt.xlabel('Month')
plt.ylabel('Worldwide Gross')
plt.title('Worldwide Gross by Month')

month_names = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
plt.xticks(all_movie_data['release_month'].unique(), month_names)

plt.show()

# %%
all_movie_data.loc[all_movie_data["movie"]=="The Gallows"]
# Out:
# Empty DataFrame
# Columns: [id, release_date, movie, production_budget, domestic_gross, worldwide_gross, return_on_investment, year, movie_id, primary_title, original_title, runtime_minutes, genres, averagerating, numvotes, release_month]
# Index: []

# %% [markdown]
# ### We also wanted to look at how IMDB ratings related to the profits and return on investments for movies

# %%
# Bar chart of domestic gross $ by month
plt.figure(figsize=(20, 6))
plt.bar(all_movie_data['release_month'], all_movie_data['worldwide_gross'])

plt.xlabel('Month')
plt.ylabel('Worldwide Gross')
plt.title('Worldwide Gross by Month')

month_names = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
plt.xticks(all_movie_data['release_month'].unique(), month_names)

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#Create scatterplot
sns.scatterplot(x='production_budget', y='averagerating', data=all_movie_data)

#Set axis labels and title
plt.xlabel('IMDb Rating')
plt.ylabel('Return on Investment')
plt.title('IMDB Avg. Rating')

plt.show()

# %%
#plotting imports
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')

# %%
sns.lmplot(x='return_on_investment', y='averagerating', data=all_movie_data)

# Set the axis labels and title
plt.xlabel('IMDB Average Rating')
plt.ylabel('Return on Investment')
plt.title('')

# Show the plot
plt.show()

# %% [markdown]
# ### Some statistical testing

# %%
mean_by_month = all_movie_data.groupby('release_month')['return_on_investment'].mean()
mean_by_month
# Out:
# release_month
# 1     4.575492
# 2     3.309353
# 3     2.477162
# 4     3.527193
# 5     2.987794
# 6     3.540071
# 7     4.062378
# 8     2.608681
# 9     2.559065
# 10    3.924955
# 11    3.113364
# 12    1.994744
# Name: return_on_investment, dtype: float64

# %%
# One-way ANOVA
result = stats.f_oneway(
    all_movie_data[all_movie_data['release_month'] == 1]['return_on_investment'],
    all_movie_data[all_movie_data['release_month'] == 2]['return_on_investment'],
    all_movie_data[all_movie_data['release_month'] == 3]['return_on_investment'],
    all_movie_data[all_movie_data['release_month'] == 4]['return_on_investment'],
    all_movie_data[all_movie_data['release_month'] == 5]['return_on_investment'],
    all_movie_data[all_movie_data['release_month'] == 6]['return_on_investment'],
    all_movie_data[all_movie_data['release_month'] == 7]['return_on_investment'],
    all_movie_data[all_movie_data['release_month'] == 8]['return_on_investment'],
    all_movie_data[all_movie_data['release_month'] == 9]['return_on_investment'],
    all_movie_data[all_movie_data['release_month'] == 10]['return_on_investment'],
    all_movie_data[all_movie_data['release_month'] == 11]['return_on_investment'],
    all_movie_data[all_movie_data['release_month'] == 12]['return_on_investment']
)

result
# Out:
# F_onewayResult(statistic=2.256719500977848, pvalue=0.010081449830543286)

# %% [markdown]
# #### This shows us that there is a signficant difference between the months, but not which months. To figure that out, we need to do post-hoc tests.

# %%
#One-way ANOVA
model = ols('return_on_investment ~ C(release_month)', data=all_movie_data).fit()
anova_table = sm.stats.anova_lm(model)

print("ANOVA Table:")
print(anova_table)

#Tukey HSD post hoc test
tukey_result = pairwise_tukeyhsd(all_movie_data['return_on_investment'], all_movie_data['release_month'])

print("Tukey HSD Post Hoc Test:")
print(tukey_result)
# Out:
# ANOVA Table:
#                       df        sum_sq    mean_sq        F    PR(>F)
# C(release_month)    11.0    842.120882  76.556444  2.25672  0.010081
# Residual          1578.0  53531.716382  33.923775      NaN       NaN
# Tukey HSD Post Hoc Test:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      1      2  -1.2661    0.9 -3.8502  1.3179  False
#      1      3  -2.0983 0.1747 -4.5377   0.341  False
#      1      4  -1.0483    0.9 -3.5411  1.4446  False
#      1      5  -1.5877 0.6666 -4.1829  1.0075  False
#      1      6  -1.0354    0.9 -3.5684  1.4975  False
#      1      7  -0.5131    0.9 -3.0413  2.0151  False
#      1      8  -1.9668  0.296 -4.4681  0.5345  False
#      1      9  -2.0164 0.2324 -4.4701  0.4372  False
#      1     10  -0.6505    0.9 -3.0796  1.7785  False
#      1     11  -1.4621 0.7105 -3.9387  1.0144  False
#      1     12  -2.5807 0.0168 -4.9241 -0.2374   True
#      2      3  -0.8322    0.9 -3.2208  1.5564  False
#      2      4   0.2178    0.9 -2.2254   2.661  False
#      2      5  -0.3216    0.9 -2.8691   2.226  False
#      2      6   0.2307    0.9 -2.2534  2.7148  False
#      2      7    0.753    0.9 -1.7263  3.2323  False
#      2      8  -0.7007    0.9 -3.1525  1.7512  False
#      2      9  -0.7503    0.9 -3.1535  1.6529  False
#      2     10   0.6156    0.9 -1.7625  2.9937  False
#      2     11   -0.196    0.9 -2.6226  2.2306  False
#      2     12  -1.3146 0.7443 -3.6051  0.9759  False
#      3      4     1.05    0.9 -1.2396  3.3396  False
#      3      5   0.5106    0.9   -1.89  2.9113  False
#      3      6   1.0629    0.9 -1.2703  3.3961  False
#      3      7   1.5852 0.5248 -0.7429  3.9133  False
#      3      8   0.1315    0.9 -2.1673  2.4304  False
#      3      9   0.0819    0.9  -2.165  2.3288  False
#      3     10   1.4478 0.5838 -0.7722  3.6678  False
#      3     11   0.6362    0.9 -1.6357  2.9081  False
#      3     12  -0.4824    0.9 -2.6083  1.6435  False
#      4      5  -0.5394    0.9 -2.9944  1.9156  False
#      4      6   0.0129    0.9 -2.3762   2.402  False
#      4      7   0.5352    0.9 -1.8489  2.9193  False
#      4      8  -0.9185    0.9 -3.2741  1.4371  False
#      4      9  -0.9681    0.9  -3.273  1.3367  False
#      4     10   0.3978    0.9 -1.8809  2.6764  False
#      4     11  -0.4138    0.9 -2.7431  1.9154  False
#      4     12  -1.5324 0.4836 -3.7196  0.6547  False
#      5      6   0.5523    0.9 -1.9435   3.048  False
#      5      7   1.0746    0.9 -1.4164  3.5655  False
#      5      8  -0.3791    0.9 -2.8428  2.0845  False
#      5      9  -0.4287    0.9  -2.844  1.9865  False
#      5     10   0.9372    0.9  -1.453  3.3274  False
#      5     11   0.1256    0.9 -2.3129  2.5641  False
#      5     12  -0.9931    0.9 -3.2962  1.3101  False
#      6      7   0.5223    0.9 -1.9037  2.9483  False
#      6      8  -0.9314    0.9 -3.3293  1.4666  False
#      6      9   -0.981    0.9 -3.3292  1.3672  False
#      6     10   0.3849    0.9 -1.9375  2.7073  False
#      6     11  -0.4267    0.9 -2.7988  1.9454  False
#      6     12  -1.5453 0.5017  -3.778  0.6874  False
#      7      8  -1.4537 0.6755 -3.8467  0.9393  False
#      7      9  -1.5033 0.6055 -3.8464  0.8398  False
#      7     10  -0.1374    0.9 -2.4547  2.1799  False
#      7     11   -0.949    0.9 -3.3161   1.418  False
#      7     12  -2.0676 0.0986  -4.295  0.1597  False
#      8      9  -0.0496    0.9 -2.3637  2.2644  False
#      8     10   1.3163 0.7415 -0.9716  3.6042  False
#      8     11   0.5047    0.9 -1.8336   2.843  False
#      8     12  -0.6139    0.9 -2.8107  1.5828  False
#      9     10   1.3659 0.6683 -0.8698  3.6016  False
#      9     11   0.5543    0.9 -1.7329  2.8415  False
#      9     12  -0.5643    0.9 -2.7066   1.578  False
#     10     11  -0.8116    0.9 -3.0724  1.4492  False
#     10     12  -1.9302 0.1132 -4.0443  0.1839  False
#     11     12  -1.1186 0.8635 -3.2871  1.0499  False
# ----------------------------------------------------

# %%
all_movie_data.head()
# Out:
#    id release_date                                        movie  \
# 0   2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 1   3   2019-06-07                                 Dark Phoenix
# 2   4   2015-05-01                      Avengers: Age of Ultron
# 3   7   2018-04-27                       Avengers: Infinity War
# 4   9   2017-11-17                               Justice League
#
#    production_budget  domestic_gross  worldwide_gross  return_on_investment  \
# 0          410600000       241063875       1045663875              2.546673
# 1          350000000        42762350        149762350              0.427892
# 2          330600000       459005868       1403013963              4.243841
# 3          300000000       678815482       2048134200              6.827114
# 4          300000000       229024295        655945209              2.186484
#
#    year   movie_id                                primary_title  \
# 0  2011  tt1298650  Pirates of the Caribbean: On Stranger Tides
# 1  2019  tt6565702                                 Dark Phoenix
# 2  2015  tt2395427                      Avengers: Age of Ultron
# 3  2018  tt4154756                       Avengers: Infinity War
# 4  2017  tt0974015                               Justice League
#
#                                 original_title  runtime_minutes  \
# 0  Pirates of the Caribbean: On Stranger Tides            136.0
# 1                                 Dark Phoenix            113.0
# 2                      Avengers: Age of Ultron            141.0
# 3                       Avengers: Infinity War            149.0
# 4                               Justice League            120.0
#
#                      genres  averagerating  numvotes  release_month  season
# 0  Action,Adventure,Fantasy            6.6    447624              5  Spring
# 1   Action,Adventure,Sci-Fi            6.0     24451              6  Summer
# 2   Action,Adventure,Sci-Fi            7.3    665594              5  Spring
# 3   Action,Adventure,Sci-Fi            8.5    670926              4  Spring
# 4  Action,Adventure,Fantasy            6.5    329135             11    Fall

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     return_on_investment   R-squared:                       0.015
# Model:                              OLS   Adj. R-squared:                  0.009
# Method:                   Least Squares   F-statistic:                     2.257
# Date:                  Tue, 01 Aug 2023   Prob (F-statistic):             0.0101
# Time:                          18:52:05   Log-Likelihood:                -5051.8
# No. Observations:                  1590   AIC:                         1.013e+04
# Df Residuals:                      1578   BIC:                         1.019e+04
# Df Model:                            11
# Covariance Type:              nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  4.5755      0.568      8.050      0.000       3.461       5.690
# C(release_month)[T.2]     -1.2661      0.789     -1.604      0.109      -2.815       0.282
# C(release_month)[T.3]     -2.0983      0.745     -2.816      0.005      -3.560      -0.636
# C(release_month)[T.4]     -1.0483      0.762     -1.376      0.169      -2.542       0.446
# C(release_month)[T.5]     -1.5877      0.793     -2.002      0.045      -3.143      -0.032
# C(release_month)[T.6]     -1.0354      0.774     -1.338      0.181      -2.553       0.483
# C(release_month)[T.7]     -0.5131      0.772     -0.664      0.507      -2.028       1.002
# C(release_month)[T.8]     -1.9668      0.764     -2.574      0.010      -3.466      -0.468
# C(release_month)[T.9]     -2.0164      0.750     -2.690      0.007      -3.487      -0.546
# C(release_month)[T.10]    -0.6505      0.742     -0.877      0.381      -2.106       0.805
# C(release_month)[T.11]    -1.4621      0.757     -1.932      0.053      -2.946       0.022
# C(release_month)[T.12]    -2.5807      0.716     -3.605      0.000      -3.985      -1.176
# ==============================================================================
# Omnibus:                     2061.914   Durbin-Watson:                   0.931
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           413964.204
# Skew:                           6.934   Prob(JB):                         0.00
# Kurtosis:                      80.821   Cond. No.                         14.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
january_data = all_movie_data.loc[all_movie_data['release_month'] == 1]

# Create the histogram
plt.hist(january_data['return_on_investment'], bins=10, alpha=0.7, edgecolor='black')

# Customize the plot
plt.xlabel('Return on Investment')
plt.ylabel('Frequency')
plt.title('Movie Releases in January')

# Display the histogram
plt.show()

# %%
alpha = 0.05
january = all_movie_data.loc[all_movie_data['release_month']==10]
other_months = all_movie_data.loc[all_movie_data['release_month']!=10]

# %%
statistic, pvalue = stats.ttest_ind(january['return_on_investment'], other_months['return_on_investment'], equal_var=False)
pvalue / 2
# Out:
# 0.089627635116844

# %%
t_statistic, p_value = stats.ttest_ind(january['return_on_investment'], other_months['return_on_investment'], equal_var=False)
pvalue
# Out:
# 0.179255270233688

# %%
other_months
# Out:
#       id release_date                                        movie  \
# 0      2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 1      3   2019-06-07                                 Dark Phoenix
# 2      4   2015-05-01                      Avengers: Age of Ultron
# 3      7   2018-04-27                       Avengers: Infinity War
# 4      9   2017-11-17                               Justice League
# ...   ..          ...                                          ...
# 1586  59   2011-11-25                                   The Ridges
# 1587  62   2014-12-31                         Stories of Our Lives
# 1588  73   2012-01-13                                    Newlyweds
# 1589  78   2018-12-31                                       Red 11
# 1590  81   2015-09-29                         A Plague So Pleasant
#
#       production_budget  domestic_gross  worldwide_gross  \
# 0             410600000       241063875       1045663875
# 1             350000000        42762350        149762350
# 2             330600000       459005868       1403013963
# 3             300000000       678815482       2048134200
# 4             300000000       229024295        655945209
# ...                 ...             ...              ...
# 1586              17300               0                0
# 1587              15000               0                0
# 1588               9000            4584             4584
# 1589               7000               0                0
# 1590               1400               0                0
#
#       return_on_investment  year   movie_id  \
# 0                 2.546673  2011  tt1298650
# 1                 0.427892  2019  tt6565702
# 2                 4.243841  2015  tt2395427
# 3                 6.827114  2018  tt4154756
# 4                 2.186484  2017  tt0974015
# ...                    ...   ...        ...
# 1586              0.000000  2011  tt1781935
# 1587              0.000000  2014  tt3973612
# 1588              0.509333  2012  tt1880418
# 1589              0.000000  2018  tt7837402
# 1590              0.000000  2015  tt2107644
#
#                                     primary_title  \
# 0     Pirates of the Caribbean: On Stranger Tides
# 1                                    Dark Phoenix
# 2                         Avengers: Age of Ultron
# 3                          Avengers: Infinity War
# 4                                  Justice League
# ...                                           ...
# 1586                                   The Ridges
# 1587                         Stories of Our Lives
# 1588                                    Newlyweds
# 1589                                       Red 11
# 1590                         A Plague So Pleasant
#
#                                    original_title  runtime_minutes  \
# 0     Pirates of the Caribbean: On Stranger Tides            136.0
# 1                                    Dark Phoenix            113.0
# 2                         Avengers: Age of Ultron            141.0
# 3                          Avengers: Infinity War            149.0
# 4                                  Justice League            120.0
# ...                                           ...              ...
# 1586                                   The Ridges             89.0
# 1587                         Stories of Our Lives             60.0
# 1588                                    Newlyweds             95.0
# 1589                                       Red 11             77.0
# 1590                         A Plague So Pleasant             76.0
#
#                         genres  averagerating  numvotes  release_month
# 0     Action,Adventure,Fantasy            6.6    447624              5
# 1      Action,Adventure,Sci-Fi            6.0     24451              6
# 2      Action,Adventure,Sci-Fi            7.3    665594              5
# 3      Action,Adventure,Sci-Fi            8.5    670926              4
# 4     Action,Adventure,Fantasy            6.5    329135             11
# ...                        ...            ...       ...            ...
# 1586     Drama,Horror,Thriller            2.9       127             11
# 1587                     Drama            7.5        85             12
# 1588              Comedy,Drama            6.4      1436              1
# 1589    Horror,Sci-Fi,Thriller            5.6        43             12
# 1590     Drama,Horror,Thriller            5.4        72              9
#
# [1441 rows x 16 columns]

# %%
winter = all_movie_data.loc[all_movie_data['release_month'].isin([1, 2, 12])]
spring = all_movie_data.loc[all_movie_data['release_month'].isin([3, 4, 5])]
summer = all_movie_data.loc[all_movie_data['release_month'].isin([6, 7, 8])]
fall = all_movie_data.loc[all_movie_data['release_month'].isin([9, 10, 11])]

# %%
all_movie_data['season'] = all_movie_data['release_month'].map({
    1: 'Winter', 2: 'Winter', 3: 'Spring', 4: 'Spring', 5: 'Spring',
    6: 'Summer', 7: 'Summer', 8: 'Summer', 9: 'Fall', 10: 'Fall', 11: 'Fall', 12: 'Winter'
})

# %%
all_movie_data
# Out:
#       id release_date                                        movie  \
# 0      2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 1      3   2019-06-07                                 Dark Phoenix
# 2      4   2015-05-01                      Avengers: Age of Ultron
# 3      7   2018-04-27                       Avengers: Infinity War
# 4      9   2017-11-17                               Justice League
# ...   ..          ...                                          ...
# 1586  59   2011-11-25                                   The Ridges
# 1587  62   2014-12-31                         Stories of Our Lives
# 1588  73   2012-01-13                                    Newlyweds
# 1589  78   2018-12-31                                       Red 11
# 1590  81   2015-09-29                         A Plague So Pleasant
#
#       production_budget  domestic_gross  worldwide_gross  \
# 0             410600000       241063875       1045663875
# 1             350000000        42762350        149762350
# 2             330600000       459005868       1403013963
# 3             300000000       678815482       2048134200
# 4             300000000       229024295        655945209
# ...                 ...             ...              ...
# 1586              17300               0                0
# 1587              15000               0                0
# 1588               9000            4584             4584
# 1589               7000               0                0
# 1590               1400               0                0
#
#       return_on_investment  year   movie_id  \
# 0                 2.546673  2011  tt1298650
# 1                 0.427892  2019  tt6565702
# 2                 4.243841  2015  tt2395427
# 3                 6.827114  2018  tt4154756
# 4                 2.186484  2017  tt0974015
# ...                    ...   ...        ...
# 1586              0.000000  2011  tt1781935
# 1587              0.000000  2014  tt3973612
# 1588              0.509333  2012  tt1880418
# 1589              0.000000  2018  tt7837402
# 1590              0.000000  2015  tt2107644
#
#                                     primary_title  \
# 0     Pirates of the Caribbean: On Stranger Tides
# 1                                    Dark Phoenix
# 2                         Avengers: Age of Ultron
# 3                          Avengers: Infinity War
# 4                                  Justice League
# ...                                           ...
# 1586                                   The Ridges
# 1587                         Stories of Our Lives
# 1588                                    Newlyweds
# 1589                                       Red 11
# 1590                         A Plague So Pleasant
#
#                                    original_title  runtime_minutes  \
# 0     Pirates of the Caribbean: On Stranger Tides            136.0
# 1                                    Dark Phoenix            113.0
# 2                         Avengers: Age of Ultron            141.0
# 3                          Avengers: Infinity War            149.0
# 4                                  Justice League            120.0
# ...                                           ...              ...
# 1586                                   The Ridges             89.0
# 1587                         Stories of Our Lives             60.0
# 1588                                    Newlyweds             95.0
# 1589                                       Red 11             77.0
# 1590                         A Plague So Pleasant             76.0
#
#                         genres  averagerating  numvotes  release_month  season
# 0     Action,Adventure,Fantasy            6.6    447624              5  Spring
# 1      Action,Adventure,Sci-Fi            6.0     24451              6  Summer
# 2      Action,Adventure,Sci-Fi            7.3    665594              5  Spring
# 3      Action,Adventure,Sci-Fi            8.5    670926              4  Spring
# 4     Action,Adventure,Fantasy            6.5    329135             11    Fall
# ...                        ...            ...       ...            ...     ...
# 1586     Drama,Horror,Thriller            2.9       127             11    Fall
# 1587                     Drama            7.5        85             12  Winter
# 1588              Comedy,Drama            6.4      1436              1  Winter
# 1589    Horror,Sci-Fi,Thriller            5.6        43             12  Winter
# 1590     Drama,Horror,Thriller            5.4        72              9    Fall
#
# [1590 rows x 17 columns]

# %%
#One-way ANOVA
model = ols('return_on_investment ~ C(season)', data=all_movie_data).fit()
anova_table = sm.stats.anova_lm(model)

print("ANOVA Table:")
print(anova_table)

#Tukey HSD post hoc test
tukey_result = pairwise_tukeyhsd(all_movie_data['return_on_investment'], all_movie_data['season'])

print("Tukey HSD Post Hoc Test:")
print(tukey_result)
# Out:
# ANOVA Table:
#                df        sum_sq    mean_sq         F    PR(>F)
# C(season)     3.0     38.611457  12.870486  0.375679  0.770563
# Residual   1586.0  54335.225806  34.259285       NaN       NaN
# Tukey HSD Post Hoc Test:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#   Fall Spring  -0.2331    0.9 -1.2881  0.822  False
#   Fall Summer   0.1785    0.9 -0.8853 1.2423  False
#   Fall Winter  -0.1607    0.9 -1.2102 0.8887  False
# Spring Summer   0.4115 0.7392 -0.6764 1.4994  False
# Spring Winter   0.0723    0.9 -1.0016 1.1462  False
# Summer Winter  -0.3392 0.8329 -1.4217 0.7433  False
# ---------------------------------------------------
